# %% [markdown]
# # **Mosquito Indicator em Seoul, Coréia do Sul**
# [Link para o Dataset no Kaggle](https://www.kaggle.com/datasets/kukuroo3/mosquito-indicator-in-seoul-korea/data)
#
#
# ---
#
# #### **Dados**
# Este conjunto de dados trata do **Índice de Mosquitos** e das **condições climáticas (temperatura e precipitação)** em **Seul, Coreia do Sul**.
# O **Índice de Mosquitos** representa o número de mosquitos por uma determinada área específica.
#
# ---
#
# #### **Conteúdo**
# Este conjunto de dados possui **seis colunas**:
#
# - `date` – data da medição
# - `mosquito_Indica` – índice de mosquitos (quantidade por área específica)
# - `rain(mm)` – precipitação (chuva) em milímetros
# - `mean_T(℃)` – temperatura média (°C)
# - `min_T(℃)` – temperatura mínima (°C)
# - `max_T(℃)` – temperatura máxima (°C)
#
# ---
#
# #### **Período da coleta**
# Os dados foram medidos **diariamente**, entre **maio de 2016** e **dezembro de 2019**, em uma **área específica de Seul**.
#
# ---
#
# #### **Fonte:**
# Os dados foram disponibilizados neste site oficial:
# 🔗 [https://news.seoul.go.kr/welfare/mosquito](https://news.seoul.go.kr/welfare/mosquito)

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')
print(train_dataset['mosquito_Indicator'])

X = train_dataset['mosquito_Indicator']
Y = train_dataset['rain(mm)']

mediaX = np.mean(X)
mediaY = np.mean(Y)

stdX = np.std(train_dataset['mosquito_Indicator'], ddof=1)
stdY = np.std(train_dataset['rain(mm)'], ddof=1)
print('')
print("Média de Mosquitos : ", mediaX)
print("Média de precipitação : ", mediaY)
print("Desvio Padrão dos Mosquitos : ", stdX)
print("Desvio Padrão das precipitações : ", stdY)

deviationX = X - mediaX
deviationY = Y - mediaY
sumCovariance = np.sum(deviationX * deviationY)
print('')
print("Soma da Covariância : ", sumCovariance)

N = train_dataset.shape[0]

pearsonCorrelation = sumCovariance / ((N - 1) * stdX * stdY)
print('')
print("Correlação de Pearson : ", pearsonCorrelation)
# Out:
#      <input type="file" id="files-e1aa8d55-1b37-4eb0-9286-1ab31c069b14" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1aa8d55-1b37-4eb0-9286-1ab31c069b14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')

X = train_dataset['mosquito_Indicator']
Y = train_dataset['rain(mm)']

slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)

print("(Beta) Inclinação : ", slope)
print("(Alpha) Intercept : ", intercept)
print("Coeficiente Correlação : ", r_value)
print("P_Value : ", p_value)
print("Erro do Desvio Padrão : ", std_err)

plt.title('Mosquito Indicator')
plt.xlabel('Número de Mosquitos em uma área específica')
plt.ylabel('Precipitação (mm)')
plt.plot(X, Y, 'o', label='original_data')
plt.plot(X, intercept + slope * X, 'r', label='fitted_line')
plt.legend()

plt.show()
# Out:
#      <input type="file" id="files-6458ac08-0fc5-4baa-a65c-2483d16567b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6458ac08-0fc5-4baa-a65c-2483d16567b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')

X = train_dataset['mosquito_Indicator']
Y = train_dataset['mean_T(℃)']

mediaX = np.mean(X)
mediaY = np.mean(Y)

stdX = np.std(train_dataset['mosquito_Indicator'], ddof=1)
stdY = np.std(train_dataset['mean_T(℃)'], ddof=1)
print('')
print("Média de Mosquitos : ", mediaX)
print("Média de Temperatura (℃) : ", mediaY)
print("Desvio Padrão dos Mosquitos : ", stdX)
print("Desvio Padrão das Temperaturas Médias : ", stdY)

deviationX = X - mediaX
deviationY = Y - mediaY
sumCovariance = np.sum(deviationX * deviationY)
print('')
print("Soma da Covariância : ", sumCovariance)

N = train_dataset.shape[0]

pearsonCorrelation = sumCovariance / ((N - 1) * stdX * stdY)
print('')
print("Correlação de Pearson : ", pearsonCorrelation)
# Out:
#      <input type="file" id="files-5c0aa9ce-539c-4ec8-89de-71214ac29b48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c0aa9ce-539c-4ec8-89de-71214ac29b48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')

X = train_dataset['mosquito_Indicator']
Y = train_dataset['mean_T(℃)']

slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)

print("(Beta) Inclinação : ", slope)
print("(Alpha) Intercept : ", intercept)
print("Coeficiente Correlação : ", r_value)
print("P_Value : ", p_value)
print("Erro do Desvio Padrão : ", std_err)

plt.title('Mosquito Indicator')
plt.xlabel('Número de Mosquitos em uma área específica')
plt.ylabel('Temperatura Média (℃)')
plt.plot(X, Y, 'o', label='original_data')
plt.plot(X, intercept + slope * X, 'r', label='fitted_line')
plt.legend()

plt.show()
# Out:
#      <input type="file" id="files-62b7c87f-2ab2-4b22-bc50-4a82c10d3b94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62b7c87f-2ab2-4b22-bc50-4a82c10d3b94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')

X = train_dataset['mosquito_Indicator']
Y = train_dataset['min_T(℃)']

mediaX = np.mean(X)
mediaY = np.mean(Y)

stdX = np.std(train_dataset['mosquito_Indicator'], ddof=1)
stdY = np.std(train_dataset['min_T(℃)'], ddof=1)
print('')
print("Média de Mosquitos : ", mediaX)
print("Média das Temperaturas Mínimas (℃) : ", mediaY)
print("Desvio Padrão dos Mosquitos : ", stdX)
print("Desvio Padrão das Temperaturas Mínimas : ", stdY)

deviationX = X - mediaX
deviationY = Y - mediaY
sumCovariance = np.sum(deviationX * deviationY)
print('')
print("Soma da Covariância : ", sumCovariance)

N = train_dataset.shape[0]

pearsonCorrelation = sumCovariance / ((N - 1) * stdX * stdY)
print('')
print("Correlação de Pearson : ", pearsonCorrelation)
# Out:
#      <input type="file" id="files-0fad0f6e-d9d8-462d-a9a5-45acb8ed0405" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fad0f6e-d9d8-462d-a9a5-45acb8ed0405">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')

X = train_dataset['mosquito_Indicator']
Y = train_dataset['min_T(℃)']

slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)

print("(Beta) Inclinação : ", slope)
print("(Alpha) Intercept : ", intercept)
print("Coeficiente Correlação : ", r_value)
print("P_Value : ", p_value)
print("Erro do Desvio Padrão : ", std_err)

plt.title('Mosquito Indicator')
plt.xlabel('Número de Mosquitos em uma área específica')
plt.ylabel('Temperatura Mínimas (℃)')
plt.plot(X, Y, 'o', label='original_data')
plt.plot(X, intercept + slope * X, 'r', label='fitted_line')
plt.legend()

plt.show()
# Out:
#      <input type="file" id="files-11d2feae-7d92-42b8-baed-030ffeb7840f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11d2feae-7d92-42b8-baed-030ffeb7840f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')

X = train_dataset['mosquito_Indicator']
Y = train_dataset['max_T(℃)']

mediaX = np.mean(X)
mediaY = np.mean(Y)

stdX = np.std(train_dataset['mosquito_Indicator'], ddof=1)
stdY = np.std(train_dataset['max_T(℃)'], ddof=1)
print('')
print("Média de Mosquitos : ", mediaX)
print("Média das Temperaturas Máximas (℃) : ", mediaY)
print("Desvio Padrão dos Mosquitos : ", stdX)
print("Desvio Padrão das Temperaturas Máximas : ", stdY)

deviationX = X - mediaX
deviationY = Y - mediaY
sumCovariance = np.sum(deviationX * deviationY)
print('')
print("Soma da Covariância : ", sumCovariance)

N = train_dataset.shape[0]

pearsonCorrelation = sumCovariance / ((N - 1) * stdX * stdY)
print('')
print("Correlação de Pearson : ", pearsonCorrelation)
# Out:
#      <input type="file" id="files-76e48858-d365-40cd-818f-8fb61b89d1eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76e48858-d365-40cd-818f-8fb61b89d1eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()

train_dataset = pd.read_csv('mosquito_Indicator.csv')

X = train_dataset['mosquito_Indicator']
Y = train_dataset['max_T(℃)']

slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)

print("(Beta) Inclinação : ", slope)
print("(Alpha) Intercept : ", intercept)
print("Coeficiente Correlação : ", r_value)
print("P_Value : ", p_value)
print("Erro do Desvio Padrão : ", std_err)

plt.title('Mosquito Indicator')
plt.xlabel('Número de Mosquitos em uma área específica')
plt.ylabel('Temperatura Máximas (℃)')
plt.plot(X, Y, 'o', label='original_data')
plt.plot(X, intercept + slope * X, 'r', label='fitted_line')
plt.legend()

plt.show()
# Out:
#      <input type="file" id="files-0a8d3f3c-488d-41b8-9889-a2f6fc189f59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a8d3f3c-488d-41b8-9889-a2f6fc189f59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ###  **Correlação entre Clima e Índice de Mosquitos**
#
# ####  **Chuva (Rain mm) vs. Índice de Mosquitos**
# - **Correlação: 0.21632**
# - Existe uma **correlação positiva fraca** entre a quantidade de chuva e o número de mosquitos.
# - Isso indica que, **em geral, um aumento na precipitação tende a estar associado a um aumento na quantidade de mosquitos**, mas essa relação é **bastante fraca**.
# - Sugere-se que a água em excesso **pode ser um fator limitante**, mas **não é decisivo** para a proliferação dos mosquitos.
#
# ---
#
# ####  **Temperatura Média (mean_T ℃) vs. Índice de Mosquitos**
# - **Correlação: 0.73074**
# - Há uma **correlação positiva moderada** entre a temperatura média e o número de mosquitos.
# - Isso significa que, **à medida que a temperatura média aumenta, o número de mosquitos também tende a aumentar**.
#
# ---
#
# ####**Temperatura Mínima (min_T ℃) vs. Índice de Mosquitos**
# - **Correlação: 0.74627**
# - Existe uma **correlação positiva moderadamente forte** entre a temperatura mínima e o índice de mosquitos.
# - Isso implica que os **mosquitos tendem a se proliferar mais quando as temperaturas mínimas são mais altas**, favorecendo sua sobrevivência mesmo durante a noite.
#
# ---
#
# #### **Temperatura Máxima (max_T ℃) vs. Índice de Mosquitos**
# - **Correlação: 0.700928**
# - Há uma **correlação positiva moderada** entre a temperatura máxima e o número de mosquitos.
# - Portanto, **à medida que a temperatura máxima aumenta (provavelmente com maior incidência solar), o número de mosquitos também tende a crescer**.
#
# ---
